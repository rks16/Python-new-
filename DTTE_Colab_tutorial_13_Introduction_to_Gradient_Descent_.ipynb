061, 29.168976996325373, 29.028604053182406, 28.893566019660074, 28.76363821499607, 28.63860543396913, 28.51826154727657, 28.402409118765796, 28.29085903880859, 28.18343017313737, 28.07994902649166, 27.98024942044991, 27.88417218484843, 27.791564862214543, 27.702281424664854, 27.616182002743308, 27.533132625694925, 27.453004972693684, 27.37567613456175, 27.30102838553827, 27.228948964673396, 27.15932986644196, 27.09206764018791, 27.027063198026564, 26.964221630849103, 26.903452032086278, 26.844667328905054, 26.78778412052427, 26.732722523349413, 26.679406022638254, 26.62776133042278, 26.57771824942288, 26.529209542699483, 26.48217080880506, 26.43654036219903, 26.392259118707315, 26.349270485811857, 26.30752025756748, 26.266956513950337, 26.22752952445134, 26.189191655735403, 26.151897283195225, 26.115602706234895, 26.08026606712662, 26.045847273289475, 26.0123079228461, 25.9796112333187, 25.947721973332637, 25.91660639719984, 25.886232182261747, 25.856568368874047, 25.827585302923158, 25.79925458076651, 25.771548996495284, 25.744442491421083, 25.717910105693004, 25.691927931955323, 25.666473070959498, 25.641523589048163, 25.617058477432 ...

# %% [markdown]
# This trained model is showing vast improvements after it’s full training cycle. We can examine further by inspecting its final predicted coefficients $a$, $b$ and $c$.

# %%
print(f"Final Coefficients predicted: {GD[1]}")
print(f"Original Coefficients: {coeffs}")
# Out:
# Final Coefficients predicted: (0.9998286679732207, 0.00043719252168906314, 0.004953160902263021)
# Original Coefficients: [1, 0, 0]

# %% [markdown]
# Not too far off! A big improvement over the initial random model. Looking at the plot of the loss reduction over training offers further insights.

# %%
plt.figure(figsize=(12, 6))
plt.plot(GD[3], 'b-', label = 'loss')
plt.title('Loss over 500 iterations')
plt.legend(loc="lower right")
plt.xlabel('Iterations')
plt.ylabel('MSE')
plt.show()

# %% [markdown]
# We observe that the model loss reached close to zero, to give us our more accurate coefficients. We can also see there was no major improvement in loss after about 100 epochs. An alternative strategy would be to add some kind of condition to the training step that stops training when a certain minimum loss threshold has been reached. This would prevent excessive training and potential over-fitting for the model.

# %% [markdown]
# # Things to try
#
#
#
# 1.   Change the coefficients array and try a different polynomial instead of our $x^2$.
# 2.   Increase/decrease the learning rate to see how many iterations will be take to coverge. Does it even converge on a huge learning rate?
# 3. Take a degree 5 polynomial with 5 roots and try different initializations, instead of random ones. Does it converge on different values for different initializations? Why does initialization not matter in our case of $x^2$?
# 4. Can you modify the algorithm to find a maxima of a function, instead of a minima?

# %% [markdown]
# #Answers :

# %% [markdown]
# Answer 1:

# %%
def eval_cubic_degree(coeffs, x):

    a = coeffs[0] * (x ** 3)
    b = coeffs[1] * (x ** 2)
    c = coeffs[2] * x
    d = coeffs[3]
    y = a + b + c + d

    return y

# %%
cubic_coeffs = (random.randrange(-10, 10), random.randrange(-10, 10), random.randrange(-10, 10), random.randrange(-10, 10))
xs_values = np.random.uniform(-10, 10, 100)


xs_cubic = []
ys_cubic = []
for x in xs_values:
    y = eval_cubic_degree(cubic_coeffs, x)
    xs_cubic.append(x)
    ys_cubic.append(y)

plt.figure(figsize=(8, 6))
plt.plot(xs_cubic, ys_cubic, 'r+')
plt.title('cubic polynomial data')
plt.show()

# %%
rand_coeffs = (random.randrange(-10, 10), random.randrange(-10, 10), random.randrange(-10, 10))
y_bar = eval_2nd_degree(rand_coeffs, xs_values)

plt.figure(figsize=(8, 6))
plt.plot(xs, ys, 'g+', label = 'original data')
plt.plot(xs_cubic, y_bar, 'r.', label = 'prediction data')
plt.title('Original data vs first prediction')
plt.legend(loc="lower right")
plt.show()

# %%
initial_model_loss = loss_mse(ys, y_bar)
print(initial_model_loss)
# Out:
# 9273.992325543886

# %% [markdown]
# Answer 2:

# %%
learning_rates = [0.1, 0.001, 0.001]

results = []

for lr in learning_rates:

    rand_coeffs = (random.randrange(-10, 10), random.randrange(-10, 10), random.randrange(-10, 10))

    GD = gradient_descent(50000, lr) # Output of GD function: (updated_model_loss, new_model_coeffs, new_y_bar, list_of_loss_updates)

    results.append((lr, GD[3])) # (learning rate, list_of_loss_updates)

# Plot the loss updates for different learning rates
plt.figure(figsize=(8, 4))
for lr, losses in results:
    plt.plot(losses, label=f'LR: {lr}')

plt.title('Loss updates for different learning rates')
plt.xlabel('Iterations')
plt.ylabel('MSE')
plt.legend()
plt.show()
# Out:
# <ipython-input-64-3e15a3826a00>:12: RuntimeWarning: overflow encountered in multiply
#   return sum((ys - y_bar) * (ys - y_bar)) / len(ys)
# <ipython-input-70-bad7532be911>:22: RuntimeWarning: overflow encountered in double_scalars
#   partial_a = x_squared * (y - y_bar)
# <ipython-input-70-bad7532be911>:33: RuntimeWarning: overflow encountered in double_scalars
#   gradient_b = (-2 / n) * sum(b_s)
# <ipython-input-70-bad7532be911>:34: RuntimeWarning: overflow encountered in double_scalars
#   gradient_c = (-2 / n) * sum(c_s)
# <ipython-input-60-7687bfd0d453>:18: RuntimeWarning: invalid value encountered in add
#   y = a + b + c
e+164, 1.6513042736256707e+165, 2.2356767292279363e+166, 3.026850058733854e+167, 4.098008069897055e+168, 5.548233250763097e+169, 7.511671934224983e+170, 1.01699428804048e+172, 1.3768937075041127e+173, 1.8641562731067771e+174, 2.5238539413929074e+175, 3.41700897579184e+176, 4.626238527178032e+177, 6.263396749019877e+178, 8.479921345422463e+179, 1.1480841611351571e+181, 1.5543743713624615e+182, 2.1044447507746927e+183, 2.8491770005068134e+184, 3.857459112304397e+185, 5.222557531684903e+186, 7.070744336539412e+187, 9.572977448191868e+188, 1.2960714298495156e+190, 1.7547321722662647e+191, 2.375706250035769e+192, 3.2164339810158703e+193, 4.3546829723067954e+194, 5.89574165 ...

# %% [markdown]
# Answer 3 :

# %%
def eval_fifth_degree(coeffs, x):

    a = coeffs[0] * (x ** 5)
    b = coeffs[1] * (x ** 4)
    c = coeffs[2] * (x ** 3)
    d = coeffs[3] * (x ** 2)
    e = coeffs[4] * x
    f = coeffs[5]

    y = a + b + c + d + e + f

    return y

# %%
def calc_gradient_5th_poly_for_GD(coeffs, inputs_x, outputs_y, lr):

    a_s = []
    b_s = []
    c_s = []
    d_s = []
    e_s = []
    f_s = []

    y_bars = eval_fifth_degree(coeffs, inputs_x)

    for x,y,y_bar in list(zip(inputs_x, outputs_y, y_bars)):    # take tuple of (x datapoint, actual y label, predicted y label)

        partial_a = x**5 * (y - y_bar)
        a_s.append(partial_a)
        partial_b = x**4 * (y - y_bar)
        b_s.append(partial_b)
        partial_c = x**3 * (y - y_bar)
        c_s.append(partial_c)
        partial_d = x**2 * (y - y_bar)
        d_s.append(partial_d)
        partial_e = x * (y - y_bar)
        e_s.append(partial_e)
        partial_f = (y - y_bar)
        f_s.append(partial_f)

    num = [i for i in y_bars]
    n = len(num)

    gradient_a = (-2 / n) * sum(a_s)
    gradient_b = (-2 / n) * sum(b_s)
    gradient_c = (-2 / n) * sum(c_s)
    gradient_d = (-2 / n) * sum(d_s)
    gradient_e = (-2 / n) * sum(e_s)
    gradient_f = (-2 / n) * sum(f_s)


    a_new = coeffs[0] - lr * gradient_a
    b_new = coeffs[1] - lr * gradient_b
    c_new = coeffs[2] - lr * gradient_c
    d_new = coeffs[3] - lr * gradient_d
    e_new = coeffs[4] - lr * gradient_e
    f_new = coeffs[5] - lr * gradient_f

    new_model_coeffs = (a_new, b_new, c_new, d_new, e_new, f_new)

    # updating with these new coeffs:
    new_y_bar = eval_fifth_degree(new_model_coeffs, inputs_x)

    updated_model_loss = loss_mse(outputs_y, new_y_bar)

    return updated_model_loss, new_model_coeffs, new_y_bar


# Random initializations

hundred_xs_new = np.array([random.randint(0, x+2) for x in range(100)])
coeffs = [random.randint(0, x+2) for x in range(6)]

xs_new = []
ys_new = []
for x in hundred_xs_new:
    y  = eval_fifth_degree(coeffs, x)
    xs_new.append(x)
    ys_new.append(y)


print(type(hundred_xs_new), type(coeffs))
# Out:
# <class 'numpy.ndarray'> <class 'list'>

# %%
def gradient_descent_fifth(epochs, lr):

    losses = []
    rand_coeffs_to_test = coeffs
    for i in range(epochs):
        loss = calc_gradient_5th_poly_for_GD(rand_coeffs_to_test, hundred_xs_new, ys_new, lr)
        rand_coeffs_to_test = loss[1]
        losses.append(loss[0])
    return loss[0], loss[1], loss[2], losses  # (updated_model_loss, new_model_coeffs, new_y_bar, saved loss updates)


GD_fifth = gradient_descent_fifth(30000, 0.0003)

plt.figure(figsize=(8, 6))
plt.plot(xs_new, ys_new, 'g+', label = 'original')
plt.plot(xs_new, GD_fifth[2], 'b*', label = 'final_prediction')
plt.title('Original vs Final prediction after Gradient Descent')
plt.legend(loc = "lower right")
plt.show()

# %% [markdown]
# Answer 4:

# %%
# Random initializations

hundred_xs = np.random.uniform(-10, 10, 100)
coeffs = [1, 2, 0, 1, 1, 1]

xs_new = []
ys_new = []
for x in hundred_xs_new:
    y  = eval_fifth_degree(coeffs, x)
    xs_new.append(x)
    ys_new.append(y)


# gradient calculation
def calc_gradient_5th_poly_for_GD_max(coeffs, inputs_x, outputs_y, lr):

    a_s = []
    b_s = []
    c_s = []
    d_s = []
    e_s = []
    f_s = []

    y_bars = eval_fifth_degree(coeffs, inputs_x)

    for x, y, y_bar in zip(inputs_x, outputs_y, y_bars):

        # -ve sign is to move in the direction of a maximum
        partial_a = -x**5 * (y - y_bar)
        a_s.append(partial_a)
        partial_b = -x**4 * (y - y_bar)
        b_s.append(partial_b)
        partial_c = -x**3 * (y - y_bar)
        c_s.append(partial_c)
        partial_d = -x**2 * (y - y_bar)
        d_s.append(partial_d)
        partial_e = -x * (y - y_bar)
        e_s.append(partial_e)
        partial_f = -(y - y_bar)
        f_s.append(partial_f)

    num = [i for i in y_bars]
    n = len(num)

    gradient_a = (-2 / n) * sum(a_s)
    gradient_b = (-2 / n) * sum(b_s)
    gradient_c = (-2 / n) * sum(c_s)
    gradient_d = (-2 / n) * sum(d_s)
    gradient_e = (-2 / n) * sum(e_s)
    gradient_f = (-2 / n) * sum(f_s)

    # + sign t change rule
    a_new = coeffs[0] + lr * gradient_a
    b_new = coeffs[1] + lr * gradient_b
    c_new = coeffs[2] + lr * gradient_c
    d_new = coeffs[3] + lr * gradient_d
    e_new = coeffs[4] + lr * gradient_e
    f_new = coeffs[5] + lr * gradient_f

    new_model_coeffs = (a_new, b_new, c_new, d_new, e_new, f_new)
    new_y_bar = eval_fifth_degree(new_model_coeffs, inputs_x)
    updated_model_loss = loss_mse(outputs_y, new_y_bar)

    return updated_model_loss, new_model_coeffs, new_y_bar


# Gradient descent function for finding a maximum

def gradient_descent_fifth_max(epochs, lr):
    losses = []
    rand_coeffs_to_test = coeffs
    for i in range(epochs):
        loss = calc_gradient_5th_poly_for_GD_max(rand_coeffs_to_test, hundred_xs_new, ys, lr)
        rand_coeffs_to_test = loss[1]
        losses.append(loss[0])
    return loss[0], loss[1], loss[2], losses # (updated_model_loss, new_model_coeffs, new_y_bar, saved loss updates)


GD_ = gradient_descent_fifth_max(30000, 0.0001)

plt.figure(figsize=(8, 6))
plt.plot(xs_new, ys_new, 'g+', label = 'original')
plt.plot(xs_new, GD_[2], 'b*', label = 'final_prediction')
plt.title('Original vs Final prediction after Gradient Descent')
plt.legend(loc = "lower right")
plt.show()
# Out:
# <ipython-input-64-3e15a3826a00>:12: RuntimeWarning: overflow encountered in multiply
#   return sum((ys - y_bar) * (ys - y_bar)) / len(ys)
# <ipython-input-80-fd8af10daf41>:3: RuntimeWarning: overflow encountered in multiply
#   a = coeffs[0] * (x ** 5)
# <ipython-input-83-fb4c996fef3d>:29: RuntimeWarning: overflow encountered in double_scalars
#   partial_a = -x**5 * (y - y_bar)
# <ipython-input-83-fb4c996fef3d>:31: RuntimeWarning: overflow encountered in double_scalars
#   partial_b = -x**4 * (y - y_bar)
# <ipython-input-83-fb4c996fef3d>:33: RuntimeWarning: overflow encountered in double_scalars
#   partial_c = -x**3 * (y - y_bar)
# <ipython-input-83-fb4c996fef3d>:35: RuntimeWarning: overflow encountered in double_scalars
#   partial_d = -x**2 * (y - y_bar)
# <ipython-input-83-fb4c996fef3d>:37: RuntimeWarning: overflow encountered in double_scalars
#   partial_e = -x * (y - y_bar)
# <ipython-input-83-fb4c996fef3d>:45: RuntimeWarning: overflow encountered in double_scalars
#   gradient_a = (-2 / n) * sum(a_s)
# <ipython-input-83-fb4c996fef3d>:48: RuntimeWarning: overflow encountered in double_scalars
#   gradient_d = (-2 / n) * sum(d_s)
# <ipython-input-83-fb4c996fef3d>:49: RuntimeWarning: overflow encountered in double_scalars
#   gradient_e = (-2 / n) * sum(e_s)
# <ipython-input-80-fd8af10daf41>:3: RuntimeWarning: invalid value encountered in multiply
#   a = coeffs[0] * (x ** 5)
# <ipython-input-80-fd8af10daf41>:4: RuntimeWarning: invalid value encountered in multiply
#   b = coeffs[1] * (x ** 4)
# <ipython-input-80-fd8af10daf41>:5: RuntimeWarning: invalid value encountered in multiply
#   c = coeffs[2] * (x ** 3)
# <ipython-input-80-fd8af10daf41>:6: RuntimeWarning: invalid value encountered in multiply
#   d = coeffs[3] * (x ** 2)
# <ipython-input-80-fd8af10daf41>:7: RuntimeWarning: invalid value encountered in multiply
#   e = coeffs[4] * x

# %%
# loss history

plt.figure(figsize=(10, 4))
plt.plot(GD[3], 'b-', label = 'loss')
plt.title('Loss over 30000 iterations')

plt.xlabel('Iterations')
plt.ylabel('MSE')
plt.legend(loc="lower right")
plt.show()
