# %% [markdown]
# <a href="https://colab.research.google.com/github/rks16/Python-new-/blob/main/DTTE_Colab_tutorial_17_GiniImpurity_Generalizability.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Classification II : Information Metrics and generalizability of Decision Trees
#
# **RECAP:**
#
# In the last lab, we learnt:
#
# - What is a decision tree and how is a DT used to made a prediction.
# - How the complexity of tree effects its performance. (An example where increasing the complexity improves the performance.)
# - Notion of Entropy and Information Gain and how they can be used to create a tree.
# - Nature of decision boundaries made by DTs.
#
#
# **In this lab:**
#
# - Introduction to Gini Index and how can it be used to create decision tree.
# - Curse of Overfitting and how it affects decision trees.
# - Application of Decision Trees on a real dataset and further experiments.

# %% [markdown]
# ---
#
# ## Gini Impurity:
#
# Gini Impurity is another metric like Entropy which can be used to score a group's homogenity.
# A group's Gini Impurity is given by:
#
# $$ \text{Gini Index} = 1 - \sum_{i=1}^{c} p_i^2 $$
#
# Whichever division leads to minimum impurity among the divided class is chosen to be the split at that stage.
#
# `Impurity of a division =  Weighted sum of the impurity of the subgroups made after the division`
#
# Among Gini impurity and Information Gain, there isn't a clear cut better method of developing a decision tree. Though many a times Gini Impurity is the preferred method since it is computationally lesser expensive.
#
# ---

# %%
#Importing the necessary packages

from sklearn.datasets import load_iris
from sklearn import tree
from sklearn.model_selection import train_test_split
import pandas
import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
import matplotlib.pyplot as plt

# %%
def performExperiment(trainSet : tuple, testSet : tuple, max_depth : int = None, feature_names : list = None, class_names : list = None, criterion = "gini", min_samples_split : int = 2 , min_samples_leaf = 1, drawTree = (8,6)):
  #Importing the Decision tree classifier from sklearn:

  clf = tree.DecisionTreeClassifier(max_depth = max_depth, \
                                    criterion = criterion,\
                                    min_samples_split = min_samples_split,\
                                    min_samples_leaf = min_samples_leaf,\
                                    splitter = "best",\
                                    random_state = 0,\
                                    )
  X_train, y_train = trainSet
  X_test, y_test = testSet

  clf = clf.fit(X_train, y_train)

  y_pred = clf.predict(X_test)

  print("Accuracy of the decision tree on the test set: \n\n{:.3f}\n\n".format(accuracy_score(y_pred, y_test)))

  # Calculate confusion matrix
  confusion = np.zeros((len(class_names), len(class_names)), dtype=int)
  for true_label, predicted_label in zip(y_test, y_pred):
      confusion[true_label, predicted_label] += 1

  print("The confusion matrix is:")
  print(confusion)

  # Plot confusion matrix using matplotlib
  plt.figure(figsize=(len(class_names), len(class_names)))
  plt.imshow(confusion, interpolation='nearest', cmap=plt.cm.Blues)
  plt.title("Confusion Matrix")
  plt.colorbar()
  tick_marks = np.arange(len(class_names))
  plt.xticks(tick_marks, class_names, rotation=45)
  plt.yticks(tick_marks, class_names)
  plt.xlabel('Predicted')
  plt.ylabel('True')
  plt.show()

  if drawTree:
    print("Here is a diagram of the tree created to evaluate each sample:")
    fig, ax = plt.subplots(figsize=drawTree)
    imgObj = tree.plot_tree(clf, filled=True, ax=ax, feature_names = feature_names, class_names = class_names, impurity=False, proportion=True, rounded=True, fontsize = 10)
    plt.show()

def returnAccuracy(trainSet : tuple, testSet : tuple, max_depth : int = None, feature_names : list = None, class_names : list = None, criterion = "gini", min_samples_split : int = 2 , min_samples_leaf = 1):
  clf = tree.DecisionTreeClassifier(max_depth = max_depth, \
                                    criterion = criterion,\
                                    min_samples_split = min_samples_split,\
                                    min_samples_leaf = min_samples_leaf,\
                                    splitter = "best",\
                                    random_state = 0,\

                                    )
  X_train, y_train = trainSet
  X_test, y_test = testSet

  clf = clf.fit(X_train, y_train)

  y_pred = clf.predict(X_test)

  return accuracy_score(y_pred, y_test)

def giveAnExample(n : int):
  performExperiment((X_train, y_train),  (X_test, y_test), feature_names = iris["feature_names"], class_names = iris["target_names"], max_depth = n)

def plotDecisionBoundary(X, y, pair, clf):
  x_min, x_max = X[:, pair[0]].min() - 1, X[:, pair[0]].max() + 1
  y_min, y_max = X[:, pair[1]].min() - 1, X[:, pair[1]].max() + 1
  xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                      np.arange(y_min, y_max, 0.1))

  y_pred = clf.predict(np.c_[xx.ravel(), yy.ravel()])
  y_pred = y_pred.reshape(xx.shape)
  plt.figure(figsize=(5,4))
  plt.contourf(xx, yy, y_pred, alpha=0.4)
  plt.scatter(X[:, pair[0]], X[:, pair[1]], c = y, s = 50, edgecolor='k')
  # plt.legend()
  plt.show()

# %% [markdown]
# Let us create a synthetic dataset

# %%
np.random.seed(0)

ar = np.vstack(     [\
                    np.random.multivariate_normal(np.array([1, 1]), 1.5 * np.array([[2, -1], [-1, 2.0]]), size = 50, ),\
                    np.random.multivariate_normal(np.array([3, 3]), 2 * np.array([[0.75, -0.5], [-0.5, 0.75]]), size = 50, )
                    ]\
              )

testAr = np.vstack(   [\
                      np.random.multivariate_normal(np.array([1, 1]), np.array([[0.5, -0.25], [-0.25, 0.5]]), size = 500, ),\
                      np.random.multivariate_normal(np.array([3, 3]), np.array([[0.75, -0.5], [-0.5, 0.75]]), size = 500, )
                      ]\
                  )
testy = np.array([0] * int((testAr.shape[0]/2)) + [1] * int((testAr.shape[0]/2)))

# %%
plt.figure(figsize=(5,4))
plt.style.use("ggplot")
plt.scatter(ar[:, 0], ar[:, 1], c = np.array(["r"] * int((ar.shape[0]/2)) + ["b"] * int((ar.shape[0]/2))), )
plt.title("Noisy Training Data")
plt.xlim((-3, 8))
plt.ylim((-3, 8))

plt.show()

plt.figure(figsize=(5,4))
plt.title("Real pattern of information")
plt.scatter(testAr[:, 0], testAr[:, 1], c = np.array(["r"] * int((testAr.shape[0]/2)) + ["b"] * int((testAr.shape[0]/2))), )

plt.xlim((-3, 8))
plt.ylim((-3, 8))
# Out:
# (-3.0, 8.0)

# %%
X = ar
y = np.array([0] * int((ar.shape[0]/2)) + [1] * int((ar.shape[0]/2)))

plt.figure(figsize=(8,6))
fro, to = 1, 15
plt.plot(range(fro, to), [returnAccuracy((X, y), (testAr, testy), max_depth = i) for i in range(fro, to)], "b.-", linewidth=0.5)
plt.ylabel("Accuracy")
plt.xlabel("Depth of the tree")
# Out:
# Text(0.5, 0, 'Depth of the tree')

# %%
def boundaryExp(d) :

  clf = tree.DecisionTreeClassifier(random_state = 0, max_depth = d)
  pair = [0, 1]
  clf.fit(X[:, pair], y)
  print("Depth = {}".format(d))
  plotDecisionBoundary(X, y, pair, clf)
  plt.show()


_ = [boundaryExp(i) for i in [1, 2, 4, 8]]
# Out:
# Depth = 1
# Depth = 2
# Depth = 4
# Depth = 8

# %%
def performExperiment(trainSet : tuple, testSet : tuple, max_depth : int = None, feature_names : list = None, class_names : list = None, criterion = "gini", min_samples_split : int = 2 , min_samples_leaf = 1, drawTree = (8,6)):
    if class_names is None:
        class_names = ["Class 0", "Class 1"]

    X_train, y_train = trainSet  # Unpack the trainSet tuple
    if feature_names is None:
        feature_names = [f"Feature {i}" for i in range(X_train.shape[1])]  # Use the correct shape

# %%
plt.style.use("default")
performExperiment((X, y), (testAr, testy), max_depth = 4, drawTree= (12, 8))

# %%
plt.style.use("default")
performExperiment((X, y), (testAr, testy), max_depth = 8, drawTree = False)

# %% [markdown]
# Now that we have looked at the curse of overfitting and its consequence on the test accuracy, let us try to delve deeper and try to understand that why is it such a serious issue especially for Decision Tree.

# %% [markdown]
# ---
#
# ## Finding Pattern out of nowhere?
#
#
# In the following cell we are generating a series of random numbers from a 2-D uncorrelated Gaussian distribution. And then we randomly assign a class to each of these datapoints. i.e There exists no real pattern in the dataset and we are simply giving them a class arbitrarily.
#
# Now let us see how out decision tree does on this when the same set is used as the test set as well.

# %%
SIZE_DECOY = 100
np.random.seed(0)
simpleDat = np.random.multivariate_normal((0, 0), [[2, 0], [0, 2]], size = SIZE_DECOY)
decoyY = np.random.randint(0, 2, size = SIZE_DECOY)
COLS = ["red", "blue"]
plt.style.use("seaborn")
plt.scatter(simpleDat[:, 0], simpleDat[:, 1], c = [COLS[i] for i in decoyY])
plt.xlim((-5, 5)), plt.ylim((-5, 5))
plt.show()
# Out:
# <ipython-input-11-f416bbc2b194>:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
clf = tree.DecisionTreeClassifier(random_state = 0)
pair = [0, 1]
clf.fit(simpleDat[:, pair], decoyY)
plt.style.use("default")
plotDecisionBoundary(simpleDat, decoyY, pair, clf)
plt.show()

performExperiment((simpleDat, decoyY), (simpleDat, decoyY), drawTree=False)

# %% [markdown]
# Wow, we see that our decision tree is able to predict the values in our train set with $100\%$  accuracy!
#
# That is not a surprise if we pay attention to the nature of Decision Trees. They are in fact capable of **adapting completely to any discrete binary function that exists**. This behavious can be explained using the point they can be seen as nothing but piecewise function definition itself.
#
# Does that mean that our decision tree has learnt something? Let us explore by testing it on another set of points taken from the same distribution.

# %%
SIZE_DECOY = 100
np.random.seed(1)
testSimpleDat = np.random.multivariate_normal((0, 0), [[2, 0], [0, 2]], size = SIZE_DECOY)
testDecoyY = np.random.randint(0, 2, size = SIZE_DECOY)
performExperiment((simpleDat, decoyY), (testSimpleDat, testDecoyY), drawTree=False)

# %% [markdown]
# We infact see that our decision tree has not learnt much since its accuracy is $48\%$ on a set that it hasn't seen before which is to be expected since there are only 2 classes to predict.

# %% [markdown]
# ---
#
# ## Experiment on Titanic Dataset
#
# `Reference Dataset taken from: https://www.kaggle.com/c/titanic/data`
#
#
# The sinking of the Titanic is one of the most infamous shipwrecks in history.
#
# On April 15, 1912, during her maiden voyage, the widely considered “unsinkable” RMS Titanic sank after colliding with an iceberg. Unfortunately, there weren’t enough lifeboats for everyone onboard, resulting in the death of 1502 out of 2224 passengers and crew.
#
# While there was some element of luck involved in surviving, it seems some groups of people were more likely to survive than others.
#
# Our task in rest of today's lab is to use decision trees to predict if a person would be able to survive or not.
#
# <table>
# <tbody>
# <tr><th><b>Variable</b></th><th><b>Definition</b></th><th><b>Key</b></th></tr>
# <tr>
# <td>survival</td>
# <td>Survival</td>
# <td>0 = No, 1 = Yes</td>
# </tr>
# <tr>
# <td>pclass</td>
# <td>Ticket class</td>
# <td>1 = 1st, 2 = 2nd, 3 = 3rd</td>
# </tr>
# <tr>
# <td>sex</td>
# <td>Sex</td>
# <td></td>
# </tr>
# <tr>
# <td>Age</td>
# <td>Age in years</td>
# <td></td>
# </tr>
# <tr>
# <td>sibsp</td>
# <td># of siblings / spouses aboard the Titanic</td>
# <td></td>
# </tr>
# <tr>
# <td>parch</td>
# <td># of parents / children aboard the Titanic</td>
# <td></td>
# </tr>
# <tr>
# <td>ticket</td>
# <td>Ticket number</td>
# <td></td>
# </tr>
# <tr>
# <td>fare</td>
# <td>Passenger fare</td>
# <td></td>
# </tr>
# <tr>
# <td>cabin</td>
# <td>Cabin number</td>
# <td></td>
# </tr>
# <tr>
# <td>embarked</td>
# <td>Port of Embarkation</td>
# <td>C = Cherbourg, Q = Queenstown, S = Southampton</td>
# </tr>
# </tbody>
# </table>

# %%
import os
os.system("wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Classification2/data/titanic/train.csv")
# Out:
# 0

# %%
import os
os.listdir()
# Out:
# ['.config', 'train.csv', 'sample_data']

# %%
import pandas as pd
trainDf = pd.read_csv("train.csv")

# %%
# Preprocessing:

trainDf.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
trainDf
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
for idx, row in trainDf.iterrows():
  if row["Sex"] == "female":
    trainDf.at[idx, "Sex"] = 0
  else:
    trainDf.at[idx, "Sex"] = 1

# %%
# Since we are only exploring, lets make a validation set out of trainDf:

trainSet, testSet = train_test_split(trainDf, random_state = 0)

# %%
def relevantInfo(df):
  X = df.iloc[:, [2, 4, 5, 6, 7, 9]]
  y = df.iloc[:, 1]

  #Preprocessing to handle the missing data using a regressor
  imp = IterativeImputer(max_iter = 10, random_state=0)
  imp.fit(X)
  newDf = imp.transform(X)

  return newDf , y.to_numpy()

# %%
trainX, trainy = relevantInfo(trainSet)
testX, testy = relevantInfo(testSet)

# %%
performExperiment((trainX, trainy), (testX, testy), max_depth = 3, feature_names=[trainDf.columns[i] for i in [2, 4, 5, 6, 7, 9]], class_names=["Died", "Survived"], drawTree=(20, 6))

# %%
MAX_DEPTH = 6 #@param {type: "slider", min: 2, max: 10}
CRITERION =  "gini" #@param ["gini", "entropy"]
MIN_SAMPLES_TO_SPLIT = 2 #@param {type:"slider", min:2, max:20, step:2}
MIN_SAMPLES_IN_LEAF = 1 #@param {type: "slider", min: 1, max: 50}

plt.style.use("default")
performExperiment((trainX, trainy),\
                  (testX, testy),\
                  max_depth = MAX_DEPTH,\
                  feature_names=[trainDf.columns[i] for i in [2, 4, 5, 6, 7, 9]],\
                  class_names=["Died", "Survived"],\
                  min_samples_split = MIN_SAMPLES_TO_SPLIT,\
                  min_samples_leaf = MIN_SAMPLES_IN_LEAF,\
                  drawTree=False)

# %% [markdown]
# Let us iterate over all the possible values for depth to find the most optimum depth possible.

# %%
plt.style.use("seaborn")
plt.figure(figsize=(8,6))
fro, to = 1, 15
plt.plot(range(fro, to), [returnAccuracy((trainX, trainy), (testX, testy), max_depth = i, min_samples_leaf=3, min_samples_split=6, criterion="entropy") for i in range(fro, to)], "g.-", linewidth=0.5)
plt.ylabel("Accuracy")
plt.xlabel("Depth of the tree")
# Out:
# <ipython-input-25-de6dadcdb08a>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")
# Text(0.5, 0, 'Depth of the tree')

# %% [markdown]
# ---
#
# End of Lab 2

# %% [markdown]
# #QUESTIONS
#
# 1. Depth's Impact: Change the depth of a decision tree on the Titanic dataset (try values like 2, 4, 6, and 8). How does accuracy on the test set change with different depths? Does deeper mean better?
#
# 2. Splitting Sensitivity: Adjust the minimum samples needed to split (min_samples_split). Start from 2 and go up (try 2, 5, 10, and 20). How does changing this affect the tree's shape and test accuracy?
#
# 3. Leaf's Size: Modify the minimum samples in a leaf (min_samples_leaf). Test values like 1, 3, 5, and 10. What does this parameter do to prevent overfitting?
#
# 4. Gini vs. Entropy: Try both Gini impurity and entropy (criterion). Compare their accuracies on the Titanic dataset. Does the choice make a big difference?
#
# 5. Optimal Combo: Experiment with the Titanic and synthetic datasets. Tweak max_depth, min_samples_split, and min_samples_leaf. Can you find settings that work well for both datasets? What patterns do you notice?

# %% [markdown]
# #Solutions

# %% [markdown]
# Answer 1:

# %%
depths = [2, 4, 6, 8, 14]

# Initialize an empty list to store accuracy values
accuracy_values = []

# Iterate over different depths
for dep in depths:

    accuracy = returnAccuracy((trainX, trainy), (testX, testy), max_depth=dep,
                              min_samples_leaf=3, min_samples_split=6, criterion="gini")
    accuracy_values.append(accuracy)
    print("Accuracy when depth {} is {}%".format(dep, round(accuracy*100, 3)), "\n")

plt.figure(figsize=(8, 6))
plt.plot(depths, accuracy_values, marker='o')

plt.xlabel('Depth of the Tree')
plt.ylabel('Accuracy on Test Set')
plt.title('Impact of Depth on Decision Tree Accuracy')
plt.grid(True)
plt.show()
# Out:
# Accuracy when depth 2 is 78.027%
#
# Accuracy when depth 4 is 82.063%
#
# Accuracy when depth 6 is 81.614%
#
# Accuracy when depth 8 is 80.717%
#
# Accuracy when depth 14 is 77.578%

# %% [markdown]
# Answer 2:

# %%
min_samples_splits = [2, 5, 10, 20]

# Initialize an empty list to store accuracy values
accuracy_values = []

# Iterate over different depths
for min_sam in min_samples_splits:

    accuracy = returnAccuracy((trainX, trainy), (testX, testy), max_depth=4,
                              min_samples_leaf=3, min_samples_split=min_sam, criterion="gini")
    accuracy_values.append(accuracy)
    print("- Accuracy when minimum samples {} is {}%".format(min_sam, round(accuracy*100, 3)), "\n")


plt.figure(figsize=(8, 6))
plt.plot(min_samples_splits, accuracy_values, marker='o')

plt.xlabel('minimum samples')
plt.ylabel('Accuracy on Test Set')
plt.title('Impact of minimum samples needed to split on Decision Tree Accuracy')
plt.grid(True)
plt.show()
# Out:
# - Accuracy when minimum samples 2 is 82.063%
#
# - Accuracy when minimum samples 5 is 82.063%
#
# - Accuracy when minimum samples 10 is 82.063%
#
# - Accuracy when minimum samples 20 is 82.063%

# %% [markdown]
# Answer 3:

# %%
min_samples_leafs = [1, 3, 5, 10]

# Initialize an empty list to store accuracy values
accuracy_values = []

# Iterate over different depths
for min_leaf in min_samples_leafs:

    accuracy = returnAccuracy((trainX, trainy), (testX, testy), max_depth=4,
                              min_samples_leaf=min_leaf, min_samples_split=6, criterion="gini")
    accuracy_values.append(accuracy)
    print("- Accuracy when minimum leaf samples {} is {}%".format(min_leaf, round(accuracy*100, 3)), "\n")


plt.figure(figsize=(8, 6))
plt.plot(min_samples_splits, accuracy_values, marker='o')

plt.xlabel('minimum leaf samples')
plt.ylabel('Accuracy on Test Set')
plt.title('Impact of minimum leaf samples needed to split on Decision Tree Accuracy')
plt.grid(True)
plt.show()
# Out:
# - Accuracy when minimum leaf samples 1 is 81.614%
#
# - Accuracy when minimum leaf samples 3 is 82.063%
#
# - Accuracy when minimum leaf samples 5 is 82.063%
#
# - Accuracy when minimum leaf samples 10 is 82.063%

# %% [markdown]
# As minimum leaf samples is increased the tree continues to prevent overfitting, and we can observe that the same accuracy after minimum leaf samples=3 because the tree's structure becomes less sensitive to further increases in this parameter.

# %% [markdown]
# Answer 4:

# %%
dt = ['gini', 'entropy']

# Initialize an empty list to store accuracy values
accuracy_values = []

# Iterate over different depths
for crit in dt:

    accuracy = returnAccuracy((trainX, trainy), (testX, testy), max_depth=4,
                              min_samples_leaf=4, min_samples_split=6, criterion=crit)
    accuracy_values.append(accuracy)
    print("- Accuracy when criterion is {} : {}%".format(crit, round(accuracy*100, 3)), "\n")
# Out:
# - Accuracy when criterion is gini : 82.063%
#
# - Accuracy when criterion is entropy : 81.614%

# %% [markdown]
# Answer 5:

# %%
from sklearn.datasets import load_iris

from sklearn.datasets import load_iris
data = load_iris()
X, y = data.data, data.target

# synthetic dataset
np.random.seed(0)
synthetic_X = np.random.rand(X.shape[0], X.shape[1])
synthetic_y = np.random.randint(0, 3, size=X.shape[0])

def perform_experiment(train_X, train_y, test_X, test_y, max_depth, min_samples_split, min_samples_leaf):
    clf = tree.DecisionTreeClassifier(
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf
    )
    clf = clf.fit(train_X, train_y)
    y_pred = clf.predict(test_X)
    accuracy = accuracy_score(test_y, y_pred)
    return accuracy


# range of hyperparameters
max_depth_values = [2, 4, 6, 8]
min_samples_split_values = [2, 5, 10, 20]
min_samples_leaf_values = [1, 3, 5, 10]

best_accuracy = 0
best_hyperparameters = None

for max_depth in max_depth_values:
    for min_samples_split in min_samples_split_values:
        for min_samples_leaf in min_samples_leaf_values:

            # Titanic dataset
            titanic_X_train, titanic_X_test, titanic_y_train, titanic_y_test = train_test_split(
                X, y, test_size=0.2, random_state=0)

            titanic_accuracy = perform_experiment(
                titanic_X_train, titanic_y_train, titanic_X_test, titanic_y_test,
                max_depth, min_samples_split, min_samples_leaf)

            # synthetic dataset
            synthetic_X_train, synthetic_X_test, synthetic_y_train, synthetic_y_test = train_test_split(
                synthetic_X, synthetic_y, test_size=0.2, random_state=0)

            synthetic_accuracy = perform_experiment(
                synthetic_X_train, synthetic_y_train, synthetic_X_test, synthetic_y_test,
                max_depth, min_samples_split, min_samples_leaf)

            # average accuracy
            average_accuracy = (titanic_accuracy + synthetic_accuracy) / 2

            # Update the best hyperparameters if necessary
            if average_accuracy > best_accuracy:
                best_accuracy = average_accuracy
                best_hyperparameters = (max_depth, min_samples_split, min_samples_leaf)

# best hyperparameters and average accuracy
print("Best Hyperparameters are:", best_hyperparameters)
print("================================================= \n")
print("- max_depth_value={}, min_samples_split_value={} and min_samples_leaf_value={}".format(max_depth, min_samples_split, min_samples_leaf), "\n")
print("- Best Average Accuracy:", round(best_accuracy*100, 3),"%")
# Out:
# Best Hyperparameters are: (4, 2, 1)
# =================================================
#
# - max_depth_value=8, min_samples_split_value=20 and min_samples_leaf_value=10
#
# - Best Average Accuracy: 73.333 %
